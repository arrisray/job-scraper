# %%
from bs4 import BeautifulSoup # For HTML parsing
import urllib.request # Website connections
import urllib.parse
import urllib.error
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
# %matplotlib inline

# %%
def text_cleaner(website):
    '''
    This function just cleans up the raw html so that I can look at it.
    Inputs: a URL to investigate
    Outputs: Cleaned text only
    '''
    try:
        site = urllib.request.urlopen(website).read()  # Connect to the job posting
    except:
        return   # Need this in case the website isn't there anymore or some other weird connection problem

    soup_obj = BeautifulSoup(site) # Get the html from the site

    for script in soup_obj(["script", "style"]):
        script.extract()  # Only need these two elements from the BS4 object



    text = soup_obj.get_text()  # Get the text from this



    lines = (line.strip() for line in text.splitlines()) # break into lines



    chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each



    text = ''.join(chunk for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line


    # Now clean out all of the unicode junk (this line works great!!!)

    try:
        text = text.decode('unicode_escape').encode('ascii', 'ignore') # Need this as some websites aren't formatted
    except:                                                            # in a way that this works, can occasionally throw
        return                                                         # an exception


    text = re.sub("[^a-zA-Z.+3]", " ", text.decode())  # Now get rid of any terms that aren't words (include 3 for d3.js)
                                                # Also include + for C++

    text = text.lower().split()  # Go to lower case and split them apart


    stop_words = set(stopwords.words("english")) # Filter out any stop words
    text = [w for w in text if not w in stop_words]



    text = list(set(text)) # Last, just get the set of these. Ignore counts (we are just looking at whether a term existed
                            # or not on the website)
    return text

# %%
# def skills_info(job = None, city = None, state = None):
def get_job_descriptions(job = None, city = None, state = None):
    '''
    This function will take a desired city/state and look for all new job postings
    on Indeed.com. It will crawl all of the job postings and keep track of how many
    use a preset list of typical data science skills. The final percentage for each skill
    is then displayed at the end of the collation.

    Inputs: The location's city and state. These are optional. If no city/state is input,
    the function will assume a national search (this can take a while!!!).
    Input the city/state as strings, such as skills_info('Chicago', 'IL').
    Use a two letter abbreviation for the state.

    Output: A bar chart showing the most commonly desired skills in the job market for
    a data scientist.
    '''

    # final_job = 'data+scientist' # searching for data scientist exact fit("data scientist" on Indeed search)
    final_job = job

    # Make sure the city specified works properly if it has more than one word (such as San Francisco)
    #if city is not None:
        #final_city = city.split()
        #final_city = '+'.join(word for word in final_city)
        #final_site_list = ['http://www.indeed.com/jobs?q=%22', final_job, '%22&l=', final_city,
        #            '%2C+', state] # Join all of our strings together so that indeed will search correctly
    final_site_list = ['http://www.indeed.com/jobs?', final_job]
    #else:
    #    final_site_list = ['http://www.indeed.com/jobs?q="', final_job, '"']

    final_site = ''.join(final_site_list) # Merge the html address together into one string
    print(final_site)

    base_url = 'http://www.indeed.com'


    try:
        html = urllib.request.urlopen(final_site).read() # Open up the front page of our search first
    except:
        'That city/state combination did not have any jobs. Exiting . . .' # In case the city is invalid
        return
    soup = BeautifulSoup(html) # Get the html from the first page

    # Now find out how many jobs there were

    num_jobs_area = soup.find(id = 'searchCount').string.encode('utf-8').decode() # Now extract the total number of jobs found
                                                                        # The 'searchCount' object has this

    job_numbers = re.findall('\d+', num_jobs_area) # Extract the total jobs found from the search result


    if len(job_numbers) > 3: # Have a total number of jobs greater than 1000
        total_num_jobs = (int(job_numbers[2])*1000) + int(job_numbers[3])
    else:
        total_num_jobs = int(job_numbers[2])

    city_title = city
    if city is None:
        city_title = 'Nationwide'

    print('There were', total_num_jobs, 'jobs found,', city_title)# Display how many jobs were found

    num_pages = total_num_jobs / 10 # This will be how we know the number of times we need to iterate over each new
                                      # search result page
    job_descriptions = [] # Store all our descriptions in this list

    for i in range(1): # int(num_pages+1)): # Loop through all of our search result pages
        print('Getting page', i)
        start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
        current_page = ''.join([final_site, '&start=', start_num])
        # Now that we can view the correct 10 job returns, start collecting the text samples from each

        html_page = urllib.request.urlopen(current_page).read() # Get the page

        page_obj = BeautifulSoup(html_page) # Locate all of the job links
        job_link_area = page_obj.find(id = 'resultsCol') # The center column on the page where the job postings exist

        job_URLS = [base_url + link.get('href') for link in job_link_area.find_all('a')] # Get the URLS for the jobs

        job_URLS = list(filter(lambda x:'clk' in x, job_URLS)) # Now get just the job related URLS


        num_job_URLS = len(job_URLS)
        print( "Num job URLS: " + str(num_job_URLS) )
        for j in range(0, num_job_URLS):
            print("Job URL " + str(j) + ": " + job_URLS[j])
            final_description = text_cleaner(job_URLS[j])
            if final_description: # So that we only append when the website was accessed correctly
                job_descriptions.append(final_description)
            sleep(1) # So that we don't be jerks. If you have a very fast internet connection you could hit the server a lot!

    print('Done with collecting the job postings!')
    print('There were', len(job_descriptions), 'jobs successfully found.')

    return job_descriptions

# %%
def parse_skills(job_descriptions):
    doc_frequency = Counter() # This will create a full counter of our terms.
    [doc_frequency.update(item) for item in job_descriptions] # List comp

    # Now we can just look at our final dict list inside doc_frequency

    # Obtain our key terms and store them in a dict. These are the key data science skills we are looking for

    prog_lang_dict = Counter({'R':doc_frequency['r'], 'Python':doc_frequency['python'],
                    'Java':doc_frequency['java'], 'C++':doc_frequency['c++'],
                    'Ruby':doc_frequency['ruby'],
                    'Perl':doc_frequency['perl'], 'Matlab':doc_frequency['matlab'],
                    'JavaScript':doc_frequency['javascript'], 'Scala': doc_frequency['scala']})

    analysis_tool_dict = Counter({'Excel':doc_frequency['excel'],  'Tableau':doc_frequency['tableau'],
                        'D3.js':doc_frequency['d3.js'], 'SAS':doc_frequency['sas'],
                        'SPSS':doc_frequency['spss'], 'D3':doc_frequency['d3']})

    hadoop_dict = Counter({'Hadoop':doc_frequency['hadoop'], 'MapReduce':doc_frequency['mapreduce'],
                'Spark':doc_frequency['spark'], 'Pig':doc_frequency['pig'],
                'Hive':doc_frequency['hive'], 'Shark':doc_frequency['shark'],
                'Oozie':doc_frequency['oozie'], 'ZooKeeper':doc_frequency['zookeeper'],
                'Flume':doc_frequency['flume'], 'Mahout':doc_frequency['mahout']})

    database_dict = Counter({'SQL':doc_frequency['sql'], 'NoSQL':doc_frequency['nosql'],
                    'HBase':doc_frequency['hbase'], 'Cassandra':doc_frequency['cassandra'],
                    'MongoDB':doc_frequency['mongodb']})


    overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
    return overall_total_skills

# %%
# Create DataFrame from dict: http://stackoverflow.com/questions/18837262/convert-python-dict-into-a-dataframe
def display_skills(overall_total_skills):
    final_frame = pd.DataFrame(list(overall_total_skills.items()), columns = ['Term', 'NumPostings']) # Convert these terms to a dataframe

    # Change the values to reflect a percentage of the postings

    final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings having that term

    # Sort the data for plotting purposes

    final_frame.sort(columns = 'NumPostings', ascending = False, inplace = True)

    # Get it ready for a bar plot

    city_title="Atlanta, GA"
    final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None,
                            title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)

    final_plot.set_ylabel('Percentage Appearing in Job Ads')
    fig = final_plot.get_figure() # Have to convert the pandas plot object to a matplotlib object


    return fig, final_frame # End of the function

# %%
job_filter = "as_and=software+engineer+c%2B%2B&as_phr=&as_any=&as_not=&as_ttl=&as_cmp=&jt=fulltime&st=&sr=directhire&salary=%2470K-%24100K&radius=25&l=atlanta%2C+ga&fromage=any&limit=10&sort=&psf=advsrch"
job_descriptions = get_job_descriptions(job=job_filter, city='Atlanta', state='GA')
overall_total_skills = parse_skills(job_descriptions)
fig, final_frame = display_skills(overall_total_skills)
# Out:
# http://www.indeed.com/jobs?as_and=software+engineer+c%2B%2B&as_phr=&as_any=&as_not=&as_ttl=&as_cmp=&jt=fulltime&st=&sr=directhire&salary=%2470K-%24100K&radius=25&l=atlanta%2C+ga&fromage=any&limit=10&sort=&psf=advsrch
# There were 69 jobs found, Atlanta
# Getting page 0
# Num job URLS: 13
# Job URL 0: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CoGF09sXw-zdG3xKBf6C9zn0yHGWI7rzt6vEqrA0D3TJMQFb2P8idBBfGVZ0FXamlXxpfi-5123MP_APKes_oYEl_37MLM14S1GtjkuSYb_R2hI-HkCyr9Ec9yGd22ZBW4c1yFEo8AaQbJ4VfbxoYYslF44ENJVbudDbNQ-TlSz_cRZyAeOjSwsyKCe9CgmYg_grdjKGEdWwq5Mc2aI1AuLIOPzKGf_SJp9JUwyef1h7BrxPB0JV-91C09K2yCTsO72SoA6CSljiIqyxsKQGXOnZ6Ktgthr-LAGkBDFEwfGir-mHpyC2suxFvZNPfh8CS8I9qjj61TNSVj82wOYKYPXr3HZcUiSELVKtJDhQDo1zSk5V9cmlXQcPcKZQNhGMvg8ZMvCS3tyQKoUfuyltVxknmd_nYmkWkp41nhYda5jkmy7JGKLgZthtYNtJLEl9pxa7MPR-z9-2CwCmf9-1129d5kYs1h05HYzzgxcRW0CnFzWkq6XaO_&p=1&sk=fd61252fdb3c2dbd
# Job URL 1: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0AZhtpF9-n9E2T8mN4skCIUE1bpBl9dQZUSfPxjZKF4eQzUVfcPKwBkRZyGgESlC-M2H-pgufKvsWihMEh8O-EGLE9LRcXn-TJ0aYDhs0g6Z-FVIQyd8wGN5AuR2_grxDVHfogkT2LubtOvKnfrooU4XJGMGj7aEQfTMLAzSitJwyBOQGlpy_hK9rBLfI4tV0aOQvLgXFpusdEo1oj95Rdf6dHSn9_Z5V6l61TcpK9qOJsVCDrig9TAwyQ0T-N_WA0BtmlyELdwZpbMNsQdmQZAQd79lq3PeSTgWLtw1fC-9Osu_yhCzjvjwemsMSz1_wwvhiEVE3nGnKa80CDnrHo69uQUK0zYtg2T6k4kw61OC_h5y0Z_W9KRTstEvwbH7kb9l6xlW61wIIorjeMmUF5V1Znm5816y22IbBZhSxc32B4p9J_UZXzTZ_jAT8FyEgxqgh0rqq_QIC0TklqT5BZ_05o5pWL4hhzOxME_LnjuYfU992sLoRuyqB3wEkTbHSIr-SjY6v58FgXjFGb0QQXxvOHCT5dVCVMHlEelw8mdGp5-wuRpl6LV0M0V9L7fRbyzy6Sw3eIJBXvusXG0wauVVBs_rri10K4=&p=2&sk=fd61252fdb3c2dbd
# Job URL 2: http://www.indeed.com/rc/clk?jk=cdb261612bae5302
# Job URL 3: http://www.indeed.com/rc/clk?jk=72f7a3fac729ccc9
# Job URL 4: http://www.indeed.com/rc/clk?jk=ff7644ea704bb64f
# Job URL 5: http://www.indeed.com/rc/clk?jk=93de982cbe78a830
# Job URL 6: http://www.indeed.com/rc/clk?jk=f418fe3db0bc0ca4
# Job URL 7: http://www.indeed.com/rc/clk?jk=490e555417cdaf0e
# Job URL 8: http://www.indeed.com/rc/clk?jk=03326c79ad3a3825
# Job URL 9: http://www.indeed.com/rc/clk?jk=49c7462ce88502bc
# Job URL 10: http://www.indeed.com/rc/clk?jk=25e86fe21754e970
# Job URL 11: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CAJjpMLDN9rctudHH6deYxJhSZ5vgDQ9UabETgIXaaI3GeFiKho5VVwT4YPhO9Ko5Vt8Yi32hEDVgxT_Cot_ZkM60wYgLX5FSdlLoZF9d1NVfUJsbZqvPAPsHR-Tzezk1iFJnlDbNoAfkQJ4YQA8XzXbXCcD3940sgSZ45WMjXQJL3AFs0KNInzw1kNu8aRCzdwlgkKCk4qneDveu3OmgEWtr4-NSwPH2yj9kWwGxqPb_PqTBkI1s8UI1TyekgBDUzbvobDr7XfipUskQCkjBze36XJy_DVn0BkVMFVyz1qyTnwCOn7s_F9foNOVxeiRDkTOQZy1xKMyyYFOATI99PzM8DI_ndGlJggediLCxXlq48m-y03Xu2G0qX8sSEIxxqiKrziMCUn_hNPwx-aRGk1ivlQWnE-pNtzoZXOMB_jvm_PaQnhdJs8Ivc6bgUJYQDMx3vUtzTSe1xFj2wHNpOBbZOwf-OdTsTSyZyCcT_uH1B2yBQoF1u97fVgdL5Ga6nb0l_3VrF-YCYbbjov0_btkoc0bo5DBYEjXpiJG5bGZL0pMKI3TXZKemxIGJCPeM=&p=3&sk=fd61252fdb3c2dbd
# Job URL 12: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0BekPq1MQcaXUv0iUriqjqaHcWGdrwcf2qdtL5GcrSrIA7etiz8fpm6IqvaDEemOYyMbX76rlcOwmQzQ9BLsxUt4M9c8-ccebtbR9Zz3xX8N5NwRT1hb135cJJy1ojW74YHFh-hg-ZgqaSP6HEHDfOb-sXKOyiXvfnfCGaaY6z3_VB7_ILDYcN8iMBc5-MssTf4ryXwTZvu1Os2xzUormUWzUuWbaIydYulz3b2EDDX9MOLzl8eoJUSBIPPEgJQfuPQ7JICxUeVYnT4sCRJO1NHZ1BDQkCI0GL4qiaJhTEHUib7NVl55APuT9oDlR6VjN9ILYBasoaa-QS-I3YqR9n4hVG514M9iePLXuzkrBvLg9xnV7SSmrAjc1wJvNwDBam6mGKUlYm-2mth8qv_gt1aiGh4M_J1vbWJwO3ESweupapNB7FCgInIFSml9-JaJBmzq44vPEqFX3jKtVjwuyOdEM3fVsh-hfsg4IbEYG27lxWRdwgWnTYLUL3vu5MBB5ArxrfvvOEgY62I63azjvnxXXg_Bz9y_FR2dRC0eGeE7iFOYz1zIQG2gFuO7r1DIyC8SiGIcWb5plLBbQjdtVaz-_SiCGI1MtL19hFJ2E0UXMl22yyuZZZ8ufbrqw3JHxYJ6U9979K80w==&p=4&sk=fd61252fdb3c2dbd
# Getting page 1
# Num job URLS: 10
# Job URL 0: http://www.indeed.com/rc/clk?jk=67c9dde985e6e093
# Job URL 1: http://www.indeed.com/rc/clk?jk=54a7a47ee0ad1d9f
# Job URL 2: http://www.indeed.com/rc/clk?jk=bb6cd3a5911aa068
# Job URL 3: http://www.indeed.com/rc/clk?jk=65316e9ac9a190c5
# Job URL 4: http://www.indeed.com/rc/clk?jk=5a0150d3278c3c1b
# Job URL 5: http://www.indeed.com/rc/clk?jk=848c0081bd427133
# Job URL 6: http://www.indeed.com/rc/clk?jk=31c73150be3d9641
# Job URL 7: http://www.indeed.com/rc/clk?jk=97c2f942315cd910
# Job URL 8: http://www.indeed.com/rc/clk?jk=3809e155fee27f14
# Job URL 9: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0A_MJcvfYr0HjKhW_zCqClooybS2kMgzeeDyiE1Ywi_1gs3cWnu3FV6WYfIV6rsJidBxPbqA-Ixu2Ol8RKPnaYEzsfdAFCHqyP80fe3j5Q6n_VR9NfTH4lGKjZiaYBuXDikJovMQ8svSyq9lXxQDduumKvkZnTR_YBT_N8IhqMtFTYdah0a1u47gQnEsYbRpoOu993MEtv3xBfye6bMOcL5juldYE7HQen1TsGconN3iF9PPl2lsDaHc0J0gYzmSa-FxsJJp-pIRDjH_wq1iv-9J8DCfhvzoH1ykH2lHS1guR3UB2YRnl49o0yj-3_23GnFQ7FZzm4a9S6N6VNFvNtvi4WJO-KKHSsIZAC8vxh0jEKITvEZPeDm_90JoRy7S8DuR58BZX2ibUhL2wtxDTBsY3gYOH9P-iL1WFWRP6VXEISXQisKo20-fJsvsMX2bIwAy-7g76LxTNRH-_DTOfL1a0ARHMWEPI65yguG6c1OUkAWdigz3BXCn_l6LcNF3N84xsAhYZ5VdyljETtqBzroAfiMtleho-s9zgCL0GVW0yBU329JKEz6Veoi0RlTwVdsJX1rxkGnj8gLfTem5e8iwjMRGA4iZ1ryYeXOhMxjCw==&p=1&sk=fd61252fdb3c2dbd
# Getting page 2
# Num job URLS: 15
# Job URL 0: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0D3_SoEHW3iVUDnDiUQFfUjxVNbY6K3gSUcxeUf5VjgRIoihCjgloITpOKsGitXNWMC6ZMzNdABvHkNDql2VDLevmGfvFFYuO9NjGNK_dczxshhiov3GS5cbQbxQTbMoONgr4kqV7DZ-w0mLY3KDm5y_OvnJT4HgvE6EYSTNXH8RnmQ8GPbKEktRdh8Wxu4Q-3ZhaL3M3M1o_AOhyAmUhfcS730ksoQCyFprTySgdozX1rjHhavWVt6ZmsYcK-SIUoldgcZWk-EIfSqfPn4KbfzYTwC3Brx2R-XAOAnESBlMO1cHZ1603fR_7XcLtBQ7PnChbnB0Em-s9buAKkQ2r9w48GUxQP6TmxfxZ2eX8h5u6aYFTJ3QlqYbGHuBfqijhSpv490mtepjhU7g2sy43RWegG6Hj87mrBwqqi8lK3QDCNy-OaVlb4AURJgFZBS4sYUU15o6L9uU3Ged_isSOOiLj37MXzEYHT2ZZMOwL5blJeR165bRLjDab3LkWsnQq2li4bPmoMN51i9URAHGVeyyKMj4L-irBsNGZpETysVLO5UodfCp6LZchVnhRRBKf9JvNJfcA63oPqq48z_fqROd9uylLTVStuNEAT5ozdlSXGvv8HbKCUjs9GSI0GakCKXxnh1UMmOP3T-4AN0duQLyNp_jjIVmkxAejgEMze83fRqn1QxgeXqd0HGwq3LApypY2kg5_jzWmP0WFalc5TPtbF28c2SxOtsQB_6_FfOWmaLQlSfFHzVXraSMOyb2qRIyFYjlUJONLwLAjPljH4HpCLew67du45sbZY1pfrNXk2r1hbfkMjATdvT_9fdz1gz6XfDpxvhbf0DZidVryEbQ6ThRrjYcsgbIuz5oX_zKzOeoAPQ8eZ-o1igwBS70huG83btxq9Fq0lYC_UaLnz78y9qNrpxYLjLhldSIP5-koX_KGLBtgTWpwG5X4xnZhiddPJaE_6o4gxrKJoXEyr0&p=1&sk=fd61252fdb3c2dbd
# Job URL 1: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0BekPq1MQcaXUv0iUriqjqaHcWGdrwcf2qdtL5GcrSrIA7etiz8fpm6IqvaDEemOYyMbX76rlcOwmQzQ9BLsxUt4M9c8-ccebtbR9Zz3xX8N5NwRT1hb135cJJy1ojW74YZBnTf_R5e548JpXCF7buUEYKtvN5zd4FxtFgHFQRR6f23oXxxE4JFQtw1smEVBgAo506XQGtssD_yTeEf_0e-qsGQd_eooTXGpiBEMKoyX12SP-Myss7utYnOqsuOgz6-hz12HZZzp5TEhGXjuNPZwdu-EP-_bihtBB5TjIz5yK-NGH26gqr1hSLh7OixUThdk0Xgi2RScw-4ZKorlDHVBveDjxwSmIti5XpSLCmm6vOGEi7NZmJR2Kkg1EnLpj3xbz8wOqskYvPcHQgU-8Afg08S0BjH01JekRm2me2aVG14EOR2pNbnNeSxaCJiWVkKkeJQK9l82T9e8wY2WgNNegen-oox1iUldsiylF0iayIG2k0Y3wvCi0bvdkc38Q_O9ritVDbl-V5em7kd6bv65uTYdKfxqMjNpjv6FvO_rkobWJMtj72SuTpBtczXIavn6MRm0ZUsG_ocfhpdaxW9NfA983TmDYZ-aLT-witI-pSM0EXx3-UyHvEJV8L3zsd-zq0vuiTTeg==&p=2&sk=fd61252fdb3c2dbd
# Job URL 2: http://www.indeed.com/rc/clk?jk=7d60b3e5ec67b4d2
# Job URL 3: http://www.indeed.com/rc/clk?jk=542fcfea78ac1387
# Job URL 4: http://www.indeed.com/rc/clk?jk=61c433da248b7ef5
# Job URL 5: http://www.indeed.com/rc/clk?jk=3b790713f5291d4b
# Job URL 6: http://www.indeed.com/rc/clk?jk=a62337509bfcf446
# Job URL 7: http://www.indeed.com/rc/clk?jk=0965b3ae6967ee4a
# Job URL 8: http://www.indeed.com/rc/clk?jk=772370ccc0108e7e
# Job URL 9: http://www.indeed.com/rc/clk?jk=41c098b077199ef9
# Job URL 10: http://www.indeed.com/rc/clk?jk=ad4925e0971c23ee
# Job URL 11: http://www.indeed.com/rc/clk?jk=9a6cb1d4a6eb4841
# Job URL 12: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0AZhtpF9-n9E2T8mN4skCIUE1bpBl9dQZUSfPxjZKF4eQzUVfcPKwBkRZyGgESlC-M2H-pgufKvsWihMEh8O-EGLE9LRcXn-TJ0aYDhs0g6Z-FVIQyd8wGN5AuR2_grxDVHfogkT2LubmeKxqwrJOB7qqx5uyZSew84dF0EZMxsbX-hkfizl-gopyzupZOO6gk6f6A4AHUVmX6ueCrPL3Kx0Uy2DZK2_mTd-KnCaH9UVn6JaTOg5qYEpEo2IqMmC63zsudCczyHZldg8flVFJxg5AEAIemc_UxeRsoL33YPKYgqHIBiisnST0eQtEpUmBR7qddcMqCNoQ1ni1SNEAB6UuMFM-O4P3SzoRQjLPgKjPGf8-pCqiJJtCOwfIw4-24IFKdkgjvGC6BVvB0YKNWKMth5YES-Ietrq8pwRWHYjZ10uvBYmYM1EP5Gd9NiQO-S1qud3J-8IiaaTwnlymPqbHTA2-R7nZzajyEuZyH47fVv5xRDjU0sNXV32wXxr9mg870FrBciqP6c_6kfI7gUMXM_0sb6o_1ijhtZh4ydLgmoYuEQq-FLpaPhxMPTqM0tbLHBbnviP-DA9V9yEGgGEdVuI5zpJeE=&p=3&sk=fd61252fdb3c2dbd
# Job URL 13: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CAJjpMLDN9rctudHH6deYxJhSZ5vgDQ9UabETgIXaaI3GeFiKho5VVwT4YPhO9Ko5Vt8Yi32hEDVgxT_Cot_ZkM60wYgLX5FSdlLoZF9d1NVfUJsbZqvPAPsHR-Tzezk1iFJnlDbNoAQh-YTO66nPAXY7Rx6ymGGhaqtb-Uz5ZZmM1ZSEZVzlPcsy-9w9pT7PMdCTGjDe2nLmdQyWQ-cqpYe7jmwTHOpNQrOy8s50pmtTruNmWaLnth4FFDLzaY_nSJWJbcHBODDh49OzO29AGCmYkwv3TBoTxBF7eEwyhyexmFHUbNI9FqIe1EccPlBggtyFm8v8-EhDGiYiJX5CIBqib3XZwOtRaEIZw4zJW_nx-CEgoq2T43YAP5ZW7IiHxh_RNouI-oLaBqww--o0CWV5Cu1Gf-2iPQX6RcjpYV_m-kQ-ux7g9GvWpPVeIXPqkCktGwEHwDOHF9ekouN9_C6UX2ZNJeeHbjh4q23mKY5xX7nj0addd9KTu--ECvu_hd0tU9ewP9Q4gGc2CMueQA78hW-Ds9EMZB9XimkMVti445T2K51VKhLzb8BELT4w=&p=4&sk=fd61252fdb3c2dbd
# Job URL 14: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CoGF09sXw-zdG3xKBf6C9zn0yHGWI7rzt6vEqrA0D3TJMQFb2P8idBBfGVZ0FXamlXxpfi-5123MP_APKes_oYEl_37MLM14S1GtjkuSYb_R2hI-HkCyr9Ec9yGd22ZBW4c1yFEo8AaQbJ4VfbxoYYMLzChmR8nWbehJg4AZwrgDn2pqiaOnimRz1pUpQTwWVAATc3rgqxdzjsuceB2yqlYY61diKUkwFLvggNvQOP2TMtnSHM3nRkxKLZbQDp-7lMz_JKVUseGa3eM_21awfyjAMkkn3Ey4eTq913q8WQrlekXZgbyxiYCgDMaRwB5VbOZawoWUSVo1cB81aerXw00b5eN-pIcnSkxUG1CBG1HBownfrX37puQwd5-mBKV52cTQP7T5kOgDX6IwmSdsW4IhgUqKpctGV_RUa7s2UzsqH0bVgL4vxqUlmLDc8qo6tXHow7SPZeg1wADjlCsCghjaZH0HwfGYdCDZPGkOC_kMAs5Me6SpGt&p=5&sk=fd61252fdb3c2dbd
# Getting page 3
# Num job URLS: 10
# Job URL 0: http://www.indeed.com/rc/clk?jk=ef64375bfaca9aa8
# Job URL 1: http://www.indeed.com/rc/clk?jk=0c82cd4de719cdee
# Job URL 2: http://www.indeed.com/rc/clk?jk=37746243e74133f6
# Job URL 3: http://www.indeed.com/rc/clk?jk=17c8f30995d28675
# Job URL 4: http://www.indeed.com/rc/clk?jk=7e905bb125fc2702
# Job URL 5: http://www.indeed.com/rc/clk?jk=966b593d932f30e8
# Job URL 6: http://www.indeed.com/rc/clk?jk=71ddb6a41e780913
# Job URL 7: http://www.indeed.com/rc/clk?jk=b29be4212c212725
# Job URL 8: http://www.indeed.com/rc/clk?jk=ea9b8847a114f5ab
# Job URL 9: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0A_MJcvfYr0HjKhW_zCqClooybS2kMgzeeDyiE1Ywi_1gs3cWnu3FV6WYfIV6rsJidBxPbqA-Ixu2Ol8RKPnaYEzsfdAFCHqyP80fe3j5Q6n_VR9NfTH4lGKjZiaYBuXDgLIRMKxFsDEaRzBQocYI_IcVd3IbBTQfxWGyqPItr7n7xAfDj0V1ZqPMZGfAclw_1gujUsqRlJZGwibMs9gGgDK1f5luamZBDhSQgy46ttQzj9VN102vE6SvbEJMX4svsjIdSHnCeq30PYySMnXdzCMv7OzgZc2tY4Dr3u1brLhTOCfHcitcdP3fIr0n3hSl4_Rh67etI-8zxMaIttwxE6dYaQ6vTYHMXqSbXS0YeW146vnkMXcXPdvSl8VuPMN11HkLXjNCEwE4fdyXzDVIFp1tbsbMuOKAA8UMLH9XhoYhcKVjWcFPpeh6w6yYfHsdsVuHguvK_jkMnT-tqlrqVPw83zflfB6CYRX-9JTAJu7Mm6AAYtMygqh_4NYMMe4bAfMv51NIueXQX77LVQ_Ky8_XDQdqtZ8ORfPUgkIPMyGRzzzOvJqaFL5O__n8dvVmD69abe09QlzBwDNMtu33EIseLyvSklJrcWacxXuaIL5g==&p=1&sk=fd61252fdb3c2dbd
# Getting page 4
# Num job URLS: 14
# Job URL 0: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0D3_SoEHW3iVUDnDiUQFfUjxVNbY6K3gSUcxeUf5VjgRIoihCjgloITpOKsGitXNWMC6ZMzNdABvHkNDql2VDLevmGfvFFYuO9NjGNK_dczxshhiov3GS5cbQbxQTbMoOMWtwiuUb6u1tmYx7uWsn2QzW-N1vHj3z1dim-MsJMNfvSGlDfa2DrSU4oeZ3qcf79Ro2Wt_iRDgwWETjdOkSNtbUKi5VQwre7FXnSGMIF9a_aO0-QfKIbu4xlfW5QdBhKOasM8tE1dNGeCDeNrkPqlcu_FEmRr5C44l8oHa9Q0R0ThfRvRgL6ZYx1dXzwRUcELpkS0y7ls7aR6ePON15FoRaH1atdhbWDXh0GeMg-UgJTfqoLD_00NwyfQOQlw05RBZ1KuIxUh_FXwsw-BUPcFuuuFdfKpt4Tff8mnfAWIubCyssfF4YxGUOz9TVv7yV4ZhfOGav-gECDW6C-fIQJiY0TlD9CFTEXHsFXneTI_2sDSMDKRGUpCv7hVqeGrO0QfvgI3_Gcd5uGIPmBbCJwojCe2OYRsjZJIZBPXBlu3NQCv4uPcJXKBUFbEzQwCJ0GrkuGdtPqMQUkT4hMCFGkXM2YyfHX7ZHh29KIvvGuDMC8jJLA0J3DvU0kXYyFgXHrk7450hIO16YBVjR1J3uUtIY6un3AixtwxTOUlzDhIbJe8brvqaDOQi6v-A0ibtW6qaiu1poQIqe_QiYBoxQ0ijQg52fSUPjnvpy8qo9GJbVeookKFSIuZI8tuUCfFVlTpJA_Aza7xuK6vPYD2vaEYL0i-SPYtd-GaMxv48rfuc-19P0ujm7W93I9dUhc2hAfvyXa9SMe2DjcplidQbO-JSuSsqXuQm849fsvM6N89bVvEjqIo5l02r97rkCKLSJHx6xvP7QfgRfwH5Qyy1ZRGRT8OoA5YxurSTgktUhcxKem2fryG3_2IWu1_66OdnvOog_fsVUxPFKOzO2ZeN8Eu&p=1&sk=fd61252fdb3c2dbd
# Job URL 1: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0BekPq1MQcaXUv0iUriqjqaHcWGdrwcf2qdtL5GcrSrIA7etiz8fpm6IqvaDEemOYyMbX76rlcOwmQzQ9BLsxUt4M9c8-ccebtbR9Zz3xX8N5NwRT1hb135cJJy1ojW74bzPXDUC4bfnLu3WX4_qD9q0PoFha4KdVoTS6qOXF5gxifdZqFZRETeQLvM8Sk6SyNgBEFVQOj2ryzG3xXPJpGXwQTK52UL4zoR_8ltRPLV52NagOOR-t1WgjYJ5jG6REk4MPiiGicshg6SoJldzqOyXLUAEfV8E6-SqIDqne1ViKiC0yeW4L-4IrN44MAK3vm23uU98bRjaA2hhDIVGamZMUKqRxMOMLxWU9LED78vto4PikmbVyhxlfg3E6H2FYcnrP-DwvJNJBcI3z3fNOlQZico-2qGygPUE70eG497RZVVjgDNaL0P-Ve26EYkP_g1BUZ6pDWsjLJ752k0y4ZZ6EzZpYRvVVk--DLOXBQFBYQSllmjxgR1JDW9HBR44a2PswwgCd3shXKKPEtmLXj1T5KNZujNLM_r32uWC_XdpoQFiaDJcNhnvM92OsqXVqJ5dUx3qBut8GF5TPG9eI9eUJe6HoX6AwsRO_-6pLWlrAjncXWgDVdSFHQerA-sIGzs6ssRMbqaUw==&p=2&sk=fd61252fdb3c2dbd
# Job URL 2: http://www.indeed.com/rc/clk?jk=78e60dc399f7b8f2
# Job URL 3: http://www.indeed.com/rc/clk?jk=68ab4340daca8e64
# Job URL 4: http://www.indeed.com/rc/clk?jk=82509c1902412e96
# Job URL 5: http://www.indeed.com/rc/clk?jk=1e2f625f156f5bb4
# Job URL 6: http://www.indeed.com/rc/clk?jk=1f8c34c5f488e309
# Job URL 7: http://www.indeed.com/rc/clk?jk=d6dfd510fdc38e6a
# Job URL 8: http://www.indeed.com/rc/clk?jk=82ee010abfbc2500
# Job URL 9: http://www.indeed.com/rc/clk?jk=8302380e442c2213
# Job URL 10: http://www.indeed.com/rc/clk?jk=809c8ca186a098ec
# Job URL 11: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0AZhtpF9-n9E2T8mN4skCIUE1bpBl9dQZUSfPxjZKF4eQzUVfcPKwBkRZyGgESlC-M2H-pgufKvsWihMEh8O-EGLE9LRcXn-TJ0aYDhs0g6Z-FVIQyd8wGN5AuR2_grxDVHfogkT2Lubi_LWhvBaNpmZ7JC31E3z99usOOL7oXhgk9eDK3QZu5BTr4hoZpyx5grfy8hIAcj3Z0BKZ1oGNYnEQI-BkGHCp8S-Oco5G0Aj8M2bEOpatEoTxigAvZjbsJI06Km27Of0u6JOWAe7J3ZrQv14rrX8gDfHnSvZUANpD9hChffnDzAOZIMTfx8Osv_JmPU1Dl4IaCvalbJU9ui9Wj86EWwUlHar4YkRoH7mPWGIrePKHuZD6g2uHQv8cUqllqgZrgvB2emINyHvSMitqA1Oq3UQcW_c3APkuSjPO1jlMji4JMgsjgx0cSO7l7bL1I_GznOJ3BkWnEXnZsrRpVWDxK2M1f_vf4Nv4iYnDygM5lzgX8EjlPzAylTpu1PhBwe186LnO0lacGAENrI5EgX2epb2J0UiGQgqtUap5NHPf1lWUx9ASPqJ7gvpOxKcSt8gc-m4HaGfUcvm8c2o1nuTYhLJwI=&p=3&sk=fd61252fdb3c2dbd
# Job URL 12: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CAJjpMLDN9rctudHH6deYxJhSZ5vgDQ9UabETgIXaaI3GeFiKho5VVwT4YPhO9Ko5Vt8Yi32hEDVgxT_Cot_ZkM60wYgLX5FSdlLoZF9d1NVfUJsbZqvPAPsHR-Tzezk1iFJnlDbNoAVtnQwH0xczM1CBAheUKFfa-ZZuaDvku736-eMemxYJrs7QRcO55xYlR79-OT5HjrkzUCHiYnshfYsJvmIvUmrjUDyqRGKKYKDUmqdlMVjmNk2PB4UA2WFiNKlePKIeb9UDEM4KR5eSQGbjmSHZINPPp1Jz-3RoJjmlsAfZRUIPXfRtsDVqvKWpGXKl8_PSgl_0Y9YfNP_etw45WURe4WRHNzRWx8qa5S__hITCL3_m6aHx7EYuFVzF2iUKX_2Xn2PRxMPo2l5C7aT-2sHtmyqqkL5ZESLAmQfmCkTaDxuC4xbZX94uLCPeJVJC3mQBzra_aq1pEBeXoJDgnh0-v-0hM_Quk_bhl8s3YFwSTE7edZY-tS_wNBZHZfRgFaJtyJ1MdUfdd0rU-BCFV6lq49JRSPuYsY5-zyB160x-Dn9jEjCQHnniZAoY=&p=4&sk=fd61252fdb3c2dbd
# Job URL 13: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CoGF09sXw-zdG3xKBf6C9zn0yHGWI7rzt6vEqrA0D3TJMQFb2P8idBBfGVZ0FXamlXxpfi-5123MP_APKes_oYEl_37MLM14S1GtjkuSYb_R2hI-HkCyr9Ec9yGd22ZBW4c1yFEo8AaQbJ4VfbxoYYfE4nCeZRRHXA0_lYMbrLiNrBpEiFmYsX4iYAB9Us3YkD-OpZvDW8DeaC-UCLL5hGetpwe7OzUjc8UdS-FhsfTJXKR7_kAErw2z39if2-2YCLBmWjqilD_tfEg6_jIC84zIt-BwBNHqbEieGAfozHKxyj6rDEAp8om-Cf2NXOgY0-MQ1M9GUcPee-Az1PO09oq73IcB8eog5BfrJVe3cWLUaEow_z6CmCnlA2sz8Qiki65om1BuHnWR-_1SfTb8xFJpToWClHMiq3TQUyzjUKfq3cpcnHRS1fpKWinmf5k4XzphARVZjX-Ok3VMtUirxHeibekmat2g-nbRZQA2QbCTQzs4Crx2wn&p=5&sk=fd61252fdb3c2dbd
# Getting page 5
# Num job URLS: 10
# Job URL 0: http://www.indeed.com/rc/clk?jk=e95f7d9d8d8e2588
# Job URL 1: http://www.indeed.com/rc/clk?jk=3ada96534e50066c
# Job URL 2: http://www.indeed.com/rc/clk?jk=4ba1c0101046bedb
# Job URL 3: http://www.indeed.com/rc/clk?jk=a3e3419dec4a4251
# Job URL 4: http://www.indeed.com/rc/clk?jk=3dc0877d7d2f689d
# Job URL 5: http://www.indeed.com/rc/clk?jk=67ba817cf6fc5fa1
# Job URL 6: http://www.indeed.com/rc/clk?jk=6895cda34a3ee80b
# Job URL 7: http://www.indeed.com/rc/clk?jk=2590442a2022c87f
# Job URL 8: http://www.indeed.com/rc/clk?jk=8be725eb2483112b
# Job URL 9: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0A_MJcvfYr0HjKhW_zCqClooybS2kMgzeeDyiE1Ywi_1gs3cWnu3FV6WYfIV6rsJidBxPbqA-Ixu2Ol8RKPnaYEzsfdAFCHqyP80fe3j5Q6n_VR9NfTH4lGKjZiaYBuXDiveid0jh78MYw2JnGpPkG7_QZKkDDQzxRj0QosfmsveiveolcFbwtRVu5giY-TbNNXoV571MKe6IJ4lsTWidmgpL1tc3ReQ5FKok1iDC6a5P3NC2i0lOvgDmMheMJ-cmehUSuaT1Y7p4qUuXozWUVIZJ9c4Ld5yaD9Xhf86aAFqJTa10quPSb-ytYK7YCW-DxaH4EIe55CGpQvJFYDMbXatHDOMdn0V78SD_yYggN6YuPtUhNadXUupOTh3kBGEBgkHqSq5T81i5P0JaWQHnB1z2zSX2DcbdKBXdqvDhg36GIqHz-GitVcDP64x-PwVDtxQinCmrRs0xcqoFxWFyp_wis3N9JiINc3QLk92LsqFIeRpNK6Iz5latQ0Z1eZmlZrcYXE58Soy8iVsJ0PktUxwVw-u3_6hVPl-m8k8uF2EMDb6BqrpYnLQeSBTzWTJwraXUVH6ODhFYRrYjbHNCL9FLzTmCEVkbF_Hx4XnQU6vQ==&p=1&sk=fd61252fdb3c2dbd
# Getting page 6
# Num job URLS: 10
# Job URL 0: http://www.indeed.com/rc/clk?jk=e95f7d9d8d8e2588
# Job URL 1: http://www.indeed.com/rc/clk?jk=3ada96534e50066c
# Job URL 2: http://www.indeed.com/rc/clk?jk=4ba1c0101046bedb
# Job URL 3: http://www.indeed.com/rc/clk?jk=a3e3419dec4a4251
# Job URL 4: http://www.indeed.com/rc/clk?jk=3dc0877d7d2f689d
# Job URL 5: http://www.indeed.com/rc/clk?jk=67ba817cf6fc5fa1
# Job URL 6: http://www.indeed.com/rc/clk?jk=6895cda34a3ee80b
# Job URL 7: http://www.indeed.com/rc/clk?jk=2590442a2022c87f
# Job URL 8: http://www.indeed.com/rc/clk?jk=8be725eb2483112b
# Job URL 9: http://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0A_MJcvfYr0HjKhW_zCqClooybS2kMgzeeDyiE1Ywi_1gs3cWnu3FV6WYfIV6rsJidBxPbqA-Ixu2Ol8RKPnaYEzsfdAFCHqyP80fe3j5Q6n_VR9NfTH4lGKjZiaYBuXDiXORFoTCjLi2eMJd0MAC-22Gtf3TzoPygoiFTTCasaMCrCUtUDxXIbsa2-P6OV8hr9imHVyCctHf_RjanwxwoaS7PhQbhysUxNRhN3fn9IpHJ2hvl5pwcyqjfcjL4W5_0FMNp88qMBXCp2WHFO9S_N1hGkoShGj2n79hQljU0SF2hE8Q4FD3-rtL3TubB3YkZoltn4cXRt9Rq-yndC4JXHfhCYLWPdL1InEl4G0OhDtw7soSeJxtXJ-1C1_4J2CYmBxT4s-T-ULyUVQJRi1fJzqEwyZDJg7GTStjdGmJE7kLXtE-bqAUjxEslsIuUscMC4K0kFU60gIzYb66t52LlbXnZZByP56za66cwX7cqpwQYltdyxWSfrDwIAOYTw90Hl9D8et8H9WuJxAgaYC5J-eLolhOMcbJaLpO9VrChUqUic57yZ2hrumOX3uDcChwQr3MA6bEdrKXiT_DoJzyDVNOasfJ45ezSODjA-2-J-8A==&p=1&sk=fd61252fdb3c2dbd
